# %%
#Name: Mohit Avinash Khambekar
#Rollno: 151
#Class: TYIT-B
#Batch: T3

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
# Fetch the dataset
df = pd.read_csv('student_scores.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# describe the dataframe
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
# Check for null records
df.isnull()
# Out:
#     Hours  Scores
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False

# %%
# Plot the distribution
plt.title('Score Distribution Plot')
sns.histplot(df['Scores'])
plt.show()

# %%
# Relationship between Scores and Hours
plt.scatter(df['Hours'], df['Scores'], color = 'blue')
plt.title('Scores vs Hours')
plt.xlabel('No Of Hours')
plt.ylabel('Scores')
plt.box(True)
plt.show()

# %%
# Splitting variables
X = df.iloc[:, :1]  
y = df.iloc[:, 1:]

# %%
# Splitting dataset into test/train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print(f"Training set size: {X_train.shape}, {y_train.shape}")
print(f"Testing set size: {X_test.shape}, {y_test.shape}")
# Out:
# Training set size: (20, 1), (20, 1)
# Testing set size: (5, 1), (5, 1)

# %%
# Regressor model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction result
y_pred_test = regressor.predict(X_test)     
y_pred_train = regressor.predict(X_train)

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'blue')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Scores vs No of hours')
plt.xlabel('No of hours')
plt.ylabel('Scores')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Scores/hours', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
# Prediction on test set
plt.scatter(X_test, y_test, color = 'blue')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Scores vs No of hours')
plt.xlabel('No of hours')
plt.ylabel('Scores')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Scores/Hours', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
# Regressor coefficients and intercept
print(f'Coefficient: {regressor.coef_}')
print(f'Intercept: {regressor.intercept_}')
# Out:
# Coefficient: [[9.91065648]]
# Intercept: [2.01816004]
